# %%
from google.colab import userdata

import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# !pip uninstall -y langchain-community
# !pip uninstall -y langchain-core
# !pip uninstall -y langchain
# Out:
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Found existing installation: langchain-core 1.2.6
# Uninstalling langchain-core-1.2.6:
#   Successfully uninstalled langchain-core-1.2.6
# Found existing installation: langchain 1.2.0
# Uninstalling langchain-1.2.0:
#   Successfully uninstalled langchain-1.2.0

# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-text-splitters
# !pip install duckduckgo-search
# Out:
# ...
#   Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langchain_core-1.2.6-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached langchain-1.2.0-py3-none-any.whl (102 kB)
# Using cached langchain_core-1.2.6-py3-none-any.whl (489 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# ...

# %%
# !pip install sentence-transformers faiss-cpu pypdf
# !pip install chromadb
# !pip install transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 86.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 6.5 MB/s eta 0:00:00
# ...

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/NEXTG_GPT.pdf")
docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

chunks = splitter.split_documents(docs)

# %%
import langchain
print(langchain.__version__)
print(langchain.__file__)
# Out:
# 1.2.0
# /usr/local/lib/python3.12/dist-packages/langchain/__init__.py

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 6})
# Out:
# /tmp/ipython-input-3434194432.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...

# %%
# !pip install langchain_huggingface

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

llm = ChatHuggingFace(
    llm=HuggingFaceEndpoint(
        repo_id="meta-llama/Meta-Llama-3.1-8B-Instruct",
        task="text-generation",
        max_new_tokens=800,
        temperature=0.2
    )
)

# %%
from langchain_core.prompts import PromptTemplate

decision_prompt = PromptTemplate(
    input_variables=["question"],
    template="""
You are an expert research assistant.

Decide whether answering the following question
requires up-to-date information from the web
or can be answered using existing research papers.

Question:
{question}

Answer ONLY with one word:
YES or NO
"""
)
decision_agent = decision_prompt | llm

# %%
def needs_web_search(question):
    decision = decision_agent.invoke({"question": question}).content.strip().upper()
    return decision == "YES"

# %%
def web_search_context(query, max_results=5):
    results = search_tool.invoke(query)
    return results

# %%
def needs_web_search(question):
    decision = decision_agent.invoke({"question": question}).content.strip().upper()
    return decision == "YES"

# %%
web_reader_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
You are a technical research assistant.

Using ONLY the web search context below,
extract the most relevant and factual information
related to the question.

Context:
{context}

Question:
{question}

Return concise bullet points.
"""
)

web_reader_agent = web_reader_prompt | llm

# %% [markdown]
# ## Query Decomposition Agent

# %%
from langchain_core.prompts import PromptTemplate
decompose_query= PromptTemplate(
    input_variables=["question"],
    template=""""
Generate 3 different search queries
that capture different technical interpretations
of the following research question.

Question:
{question}
"""

)
query_agent= decompose_query | llm

# %% [markdown]
# ## Retriever Agent

# %%
def retrive_docs(sub_query):
    docs = retriever.invoke(sub_query)
    return docs

# %% [markdown]
# ## Reader Agent (Evidence Extractor)

# %%
reader_prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""You are a research paper analyst.

Context:
{context}

Question:
{question}

Extract factual points with citations.
"""
)

reader_agent = reader_prompt | llm

# %% [markdown]
# ## Critic Agent (Validation)

# %%
critic_ptompt= PromptTemplate(
    input_variables=["context", "question", "answer"],
    template="""you are a critical review agent.

Context:
{context}

Question:
{question}

Answer:
{answer}
Return corrected version.
"""
)
critic_agent = critic_ptompt | llm

# %% [markdown]
# ## Synthesizer Agent (Final Answer)

# %%
synth_prompt=PromptTemplate(
    input_variables=["answer"],
    template="""Combine the following expert answers into one coherent response.
Ensure clarity, citations, and structured explanation.

Answers:
{answers}
"""
)
synthesizer_agent = synth_prompt | llm

# %% [markdown]
# ## Multi-Agent Orchestration

# %%
def multi_agent_rag_with_web(question):
    # Step 1: Decompose
    sub_queries = query_agent.invoke({"question": question}).content.split("\n")

    all_answers = []

    for q in sub_queries:
        current_context = ""
        # Step 2: Decide web vs papers
        if needs_web_search(q):
            web_context = web_search_context(q)
            current_context = web_context
            answer = web_reader_agent.invoke({
                "context": web_context,
                "question": q
            })
        else:
            docs = retrive_docs(q)
            context = "\n".join([d.page_content for d in docs])
            current_context = context
            answer = reader_agent.invoke({
                "context": context,
                "question": q
            })

        reviewed = critic_agent.invoke({
            "context": current_context,
            "question": q,
            "answer": answer.content
        })

        all_answers.append(reviewed.content)

    final = synthesizer_agent.invoke({
        "answers": "\n".join(all_answers)
    })

    return final.content

# %%
question = "what work GEN AI is doing wireless communcation provide me its purpose and role of this NextG gpt and how RAG is working ?"
print(multi_agent_rag_with_web(question))
# Out:
# The provided text discusses the development and deployment of NextG-GPT, a domain-specific RAG-enhanced LLM assistant designed for telecom applications, O-RAN research, and wireless experimentation. The text highlights the key features and contributions of NextG-GPT, including its integration of multiple structured datasets, real-time experimental validation, and deployment within a research testbed.
#
# **Strengths:**
#
# 1.  **Innovative Approach**: NextG-GPT introduces a transformative AI-driven approach to wireless network research by integrating RAG-LLMs, which enables the integration of a knowledge graph, reducing knowledge errors and ensuring smoother, more interactive dialogue exchanges.
# 2.  **Real-world testbed**: The deployment of NextG-GPT within the ARA Wireless Living Lab provides a real-world testbed for evaluating AI-driven wireless research, distinguishing it from previous domain-specific LLM applications.
# ...
